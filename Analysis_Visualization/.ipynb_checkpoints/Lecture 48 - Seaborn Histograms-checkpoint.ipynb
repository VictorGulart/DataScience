# %%
import numpy as np
import pandas as pd
from numpy.random import randn

# %%
# Stats
from scipy import stats

# %%
# Plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
# Histograms

# %%
dataset1 = randn(100)

# %%
# 10 bins is the usual default
plt.hist(dataset1)
# Out:
# (array([ 6.,  6., 10., 17., 18., 10., 16.,  9.,  5.,  3.]),
#  array([-1.88136776, -1.48468589, -1.08800402, -0.69132216, -0.29464029,
#          0.10204158,  0.49872345,  0.89540532,  1.29208718,  1.68876905,
#          2.08545092]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(80)
plt.hist(dataset2, color='indianred')
# Out:
# (array([ 6.,  2., 18., 16., 18.,  2.,  8.,  6.,  2.,  2.]),
#  array([-2.3297626 , -1.78799813, -1.24623366, -0.70446919, -0.16270471,
#          0.37905976,  0.92082423,  1.4625887 ,  2.00435317,  2.54611764,
#          3.08788211]),
#  <a list of 10 Patch objects>)

# %%
#same plot
plt.hist(dataset1, density=True, color='indianred', alpha=0.5, bins=20)
plt.hist(dataset2, density=True, alpha=0.5, bins=20)
# Out:
# (array([0.13843654, 0.13843654, 0.04614551, 0.04614551, 0.46145514,
#         0.36916411, 0.41530963, 0.3230186 , 0.59989168, 0.23072757,
#         0.04614551, 0.04614551, 0.27687308, 0.09229103, 0.18458206,
#         0.09229103, 0.09229103, 0.        , 0.04614551, 0.04614551]),
#  array([-2.3297626 , -2.05888036, -1.78799813, -1.51711589, -1.24623366,
#         -0.97535142, -0.70446919, -0.43358695, -0.16270471,  0.10817752,
#          0.37905976,  0.64994199,  0.92082423,  1.19170646,  1.4625887 ,
#          1.73347093,  2.00435317,  2.2752354 ,  2.54611764,  2.81699987,
#          3.08788211]),
#  <a list of 20 Patch objects>)

# %%
# now using seaborn
data1 = randn(1000)
data2 = randn(1000)

# %%
# joint distribution
sns.jointplot(data1,data2)

# %%
sns.jointplot(data1, data2, kind='hex')
